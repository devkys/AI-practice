# %%
import pandas as pd
import numpy as np
from numpy import NaN

data = pd.DataFrame(np.arange(15).reshape(3,5), columns=['A','B','C','D', 'E'])
data.D[2] = 'NaN'
data
# Out:
#     A   B   C    D   E
# 0   0   1   2    3   4
# 1   5   6   7    8   9
# 2  10  11  12  NaN  14

# %%
data.drop(['D'], axis=1)
# Out:
#     A   B   C   E
# 0   0   1   2   4
# 1   5   6   7   9
# 2  10  11  12  14
