# %%
import pandas as pd
import numpy as np
from numpy import NaN

data = pd.DataFrame(np.arange(15).reshape(3,5), columns=['A','B','C','D', 'E'])
data.D[2] = 'NaN'
data
# Out:
#     A   B   C    D   E
# 0   0   1   2    3   4
# 1   5   6   7    8   9
# 2  10  11  12  NaN  14

# %%
data.drop(['D'], axis=1)
# Out:
#     A   B   C   E
# 0   0   1   2   4
# 1   5   6   7   9
# 2  10  11  12  14

# %%
import pandas as pd
from numpy import NaN
robots = [[23, 23680,],[35, NaN], [46,47350],[27, NaN]]
data = pd.DataFrame(robots, columns=['max_speed', 'price'])
data.dropna(subset=['price'], axis=0, inplace=True)
data
# Out:
#    max_speed    price
# 0         23  23680.0
# 2         46  47350.0

# %%
import pandas as pd
from numpy import NaN
robots = [[23, 23680,],[35, NaN], [46,47350],[27, NaN]]
data = pd.DataFrame(robots, columns=['max_speed', 'price'])
data
# Out:
#    max_speed    price
# 0         23  23680.0
# 1         35      NaN
# 2         46  47350.0
# 3         27      NaN

# %%
import pandas as pd
from numpy import NaN
robots = [[23, 23680,],[35, NaN], [46,47350],[27, NaN]]
data = pd.DataFrame(robots, columns=['max_speed', 'price'])
mean = data['price'].mean()
data.replace(NaN, mean, inplace=True)
data
# Out:
#    max_speed    price
# 0         23  23680.0
# 1         35  35515.0
# 2         46  47350.0
# 3         27  35515.0

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randn(1000)
plt.hist(x, density=True, bins=np.linspace(-5,5,21))
# Out:
# (array([0.   , 0.   , 0.   , 0.   , 0.01 , 0.044, 0.092, 0.204, 0.308,
#         0.362, 0.398, 0.314, 0.146, 0.102, 0.014, 0.006, 0.   , 0.   ,
#         0.   , 0.   ]),
#  array([-5. , -4.5, -4. , -3.5, -3. , -2.5, -2. , -1.5, -1. , -0.5,  0. ,
#          0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ]),
#  <BarContainer object of 20 artists>)

# %%
import numpy as np
import pandas as pd
price = np.random.randint(100, size=8)*10000
cars = pd.DataFrame(price, columns=['price'])
cars
# Out:
#     price
# 0  120000
# 1   40000
# 2  810000
# 3  520000
# 4  420000
# 5  880000
# 6  690000
# 7  470000

# %%
group_names=['저급','중급','고급']
cars['Level'], mybin = pd.cut(cars['price'], 3, labels=group_names, retbins=True)
cars
# Out:
#     price Level
# 0  120000    저급
# 1   40000    저급
# 2  810000    고급
# 3  520000    중급
# 4  420000    중급
# 5  880000    고급
# 6  690000    고급
# 7  470000    중급

# %%
print(mybin)
# Out:
# [ 39160. 320000. 600000. 880000.]

# %%
import pandas as pd
import numpy as np
ary = [[1, 1.1, '손'], [2, 2.2, '날개'], [3, 3.3, '손']]
data = pd.DataFrame(ary, columns=['수온','상온','hand'])
data
# Out:
#    수온   상온 hand
# 0   1  1.1    손
# 1   2  2.2   날개
# 2   3  3.3    손

# %%
pd.get_dummies(data['hand'])
# Out:
#    날개  손
# 0   0  1
# 1   1  0
# 2   0  1

# %%
import pandas as pd
import numpy as np
ary = [[1, 1.1, '손'], [2, 2.2, '날개'], [3, 3.3, '손']]
data = pd.DataFrame(ary, columns=['수온','상온','hand'])
data = pd.concat([data, pd.get_dummies(data['hand'])], axis=1, sort=False)
data.drop(['hand'], axis=1, inplace=True)
data
# Out:
#    수온   상온  날개  손
# 0   1  1.1   0  1
# 1   2  2.2   1  0
# 2   3  3.3   0  1

# %%
import networkx as nx
G = nx.Graph()

# %%
G.add_node(1)
print(G.nodes())
# Out:
# [1]

# %%
G.add_node('P')
G.add_node('Hi')
print(G.nodes())
# Out:
# [1, 'P', 'Hi']

# %%
G.add_nodes_from([2,3])
print(G.nodes())
# Out:
# [1, 'P', 'Hi', 2, 3]

# %%
G.add_nodes_from([3,4])
print(G.nodes())
# Out:
# [1, 'P', 'Hi', 2, 3, 4]

# %%
import networkx as nx
nx.draw(G, with_labels = True, node_color = 'lightblue')

# %%
pip install --user decorator==4.3.0
# Out:
# Collecting decorator==4.3.0
#   Downloading decorator-4.3.0-py2.py3-none-any.whl (9.2 kB)
# Installing collected packages: decorator
# Successfully installed decorator-4.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --user networkx==2.3
# Out:
# Collecting networkx==2.3
#   Downloading networkx-2.3.zip (1.7 MB)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\keong\appdata\roaming\python\python38\site-packages (from networkx==2.3) (4.3.0)
# Building wheels for collected packages: networkx
#   Building wheel for networkx (setup.py): started
#   Building wheel for networkx (setup.py): finished with status 'done'
#   Created wheel for networkx: filename=networkx-2.3-py2.py3-none-any.whl size=1555990 sha256=cf81056363827bf9a4419293f3f3bf66baa63cb0e83b1952aa2da0b726308979
#   Stored in directory: c:\users\keong\appdata\local\pip\cache\wheels\ff\62\9e\0ed2d25fd4f5761e2d19568cda0c32716556dfa682e65ecf64
# Successfully built networkx
# Installing collected packages: networkx
# Successfully installed networkx-2.3
# Note: you may need to restart the kernel to use updated packages.
